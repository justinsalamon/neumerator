# %%
import imread
# %matplotlib inline

# %%
manuscript = imread.imread('images/neumy.bmp')

# %%
import matplotlib.pyplot as plt

# %%
my_dpi = 30
plt.figure(figsize=(577/my_dpi,216/my_dpi), dpi=my_dpi)
plt.imshow(manuscript)
plt.plot([100,100],[100,150],'r')
plt.plot([520,520],[100,150],'r')

# %%
type(manuscript)
# Out:
# numpy.ndarray

# %%
manuscript.size
# Out:
# 373896

# %%
len(manuscript)
# Out:
# 216

# %%
len(manuscript[0])
# Out:
# 577
